# %% [markdown]
# # Nama:
# # NIM:
# # Kelas:

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ## Load Our Dataset

# %%
df = pd.read_csv('berat_tinggi.csv')

# %% [markdown]
# ## EDA

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='berat', y='tinggi')
plt.title('Sebaran Nilai berat vs tinggi')
# Out:
# Text(0.5, 1.0, 'Sebaran Nilai berat vs tinggi')

# %%
df.describe()
# Out:
#             tinggi        berat
# count  8888.000000  8888.000000
# mean    159.125498    71.365302
# std      14.258305    10.729120
# min     134.881305    44.344643
# 25%     148.522565    63.557079
# 50%     153.805704    71.748643
# 75%     170.365514    79.003827
# max     195.232920    98.644868

# %%
# Looping untuk kolom 'berat' dan 'tinggi'
columns = ['berat', 'tinggi']

for col in columns:
    # Box plot
    plt.figure(figsize=(12, 6))
    sns.boxplot(x=col, data=df)
    plt.title(f'Box Plot - {col} Badan (kg)' if col == 'berat' else f'Box Plot - {col} (cm)')
    plt.xlabel(col)
    plt.ylabel('Nilai')
    plt.show()

# %%
for col in columns:
    # Histogram
    plt.figure(figsize=(12, 6))
    sns.histplot(df[col], bins=30, kde=False)
    plt.title(f'Box Plot - {col} Badan (kg)' if col == 'berat' else f'Box Plot - {col} (cm)')
    plt.xlabel(col)
    plt.ylabel('Frekuensi')
    plt.show()

# %% [markdown]
# ## Feature Engineering
# * Unsupervised tidak perlu dilakukan splitting
# 1. Drop Duplikat
# 2. Outlier Handling (opsional)-> pada step ini tidak perlu, karena berat dan tinggi masih wajar untuk nilai seperti itu
# 3. Feature Scalling

# %%
# Drop Duplicates

print(f"Dataframe dimension before duplication drop {df.shape[0]}")

df = df.drop_duplicates().reset_index(drop=True)

print(f"Dataframe dimension after duplication drop {df.shape[0]}")
# Out:
# Dataframe dimension before duplication drop 8888
# Dataframe dimension after duplication drop 8888

# %% [markdown]
# dari hasil running program diatas, tidak ada data yg duplikat

# %%
fitur_columns = ['berat', 'tinggi']
X = df[fitur_columns].values
y = df['deskripsi'].values #anotator label

# %%
# Feature Scalling
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(X)
df_scalling = pd.DataFrame(data = X_std, columns = fitur_columns )
df_scalling.describe()
# Out:
#               berat        tinggi
# count  8.888000e+03  8.888000e+03
# mean  -9.465376e-16  9.953034e-17
# std    1.000056e+00  1.000056e+00
# min   -2.518583e+00 -1.700451e+00
# 25%   -7.278008e-01 -7.436739e-01
# 50%    3.573103e-02 -3.731224e-01
# 75%    7.119833e-01  7.883579e-01
# max    2.542716e+00  2.532521e+00

# %%
X_std
# Out:
# array([[-1.2118229 , -0.07092171],
#        [-1.75281897,  0.08546572],
#        [-0.87900786,  0.16556767],
#        ...,
#        [-0.89346332, -0.02015625],
#        [-1.6141688 , -0.17762697],
#        [ 1.40264032, -0.3111536 ]], shape=(8888, 2))

# %%
df_scalling
# Out:
#          berat    tinggi
# 0    -1.211823 -0.070922
# 1    -1.752819  0.085466
# 2    -0.879008  0.165568
# 3    -0.216544  1.636598
# 4    -0.002258  1.777105
# ...        ...       ...
# 8883  0.329937  1.274490
# 8884  0.905892 -0.527475
# 8885 -0.893463 -0.020156
# 8886 -1.614169 -0.177627
# 8887  1.402640 -0.311154
#
# [8888 rows x 2 columns]

# %% [markdown]
# ## TO DO!
# - Lengkapi Code dibawah ini, untuk mengecek distribusi sebelum dan setelah dilakukan feature scalling menggunakan standar scaller

# %%
#cek grafik sebelum dan setelah scalling
# kita lihat distribusi dari variabel sebelum standar scaller dan setelah standar scaller

fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12, 5))

# Plot distribusi sebelum Standar Scaler (Isi dibawah ini)
sns.kdeplot(X[:, 0], ax=ax1, label='berat', color='steelblue', linewidth=2)
sns.kdeplot(X[:, 1], ax=ax1, label='tinggi', color='salmon', linewidth=2)
ax1.set_title('Distribusi Sebelum Standard Scaler')

# Plot distribusi setelah Standar Scaler (Isi dibawah ini)
sns.kdeplot(X_std[:, 0], ax=ax2, label='berat', color='steelblue', linewidth=2)
sns.kdeplot(X_std[:, 1], ax=ax2, label='tinggi', color='salmon', linewidth=2)
ax2.set_title('Distribusi Setelah Standard Scaler')

# Set x-labels
ax1.set_xlabel('Nilai Asli')
ax2.set_xlabel('Nilai Terstandarisasi (z-score)')

# Menampilkan legenda
ax1.legend()
ax2.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Tulis Interpretasi dari hasil evaluasi diatas :
# ### Isi disini
# 1. Sebelum menggunakan Standard Scaler
# Pada grafik di bagian kiri terlihat bahwa fitur berat dan tinggi memiliki skala yang cukup jauh berbeda. Data berat berada di rentang sekitar 50–100, sedangkan data tinggi berkisar antara 140–200. Perbedaan rentang ini dapat membuat salah satu fitur lebih dominan dibanding fitur lainnya saat digunakan dalam proses machine learning.
#
# 2. Setelah menggunakan Standard Scaler
# Pada grafik di bagian kanan, kedua fitur telah dinormalisasi menggunakan metode Standard Scaler sehingga nilainya berubah menjadi skala standar. Hasil transformasi membuat rata-rata data mendekati 0 dan standar deviasinya mendekati 1. Dengan demikian, fitur berat dan tinggi kini memiliki rentang yang lebih seimbang sehingga analisis model dapat bekerja lebih optimal.

# %% [markdown]
# ## K-means Clustering
# Pada pembahasan kali ini akan diuji 2 metode pemilihan nilai cluster (K) yang terbaik, mendekati distribusi pada label anotator.
# 1. Metode Elbow
# 2. Via-Score plot

# %% [markdown]
# ### Metode Elbow

# %%
from sklearn.cluster import KMeans
inertia = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(df_scalling.values)
    inertia.append(kmeans.inertia_)

plt.figure(figsize=(20, 10))

sns.lineplot(x=range(1, 11), y=inertia, color='#000087', linewidth = 4)
sns.scatterplot(x=range(1, 11), y=inertia, s=300, color='#800000',  linestyle='--')
plt.title('Elbow Method - Finding K value Clusters')
plt.xlabel('The Amount of K')
plt.ylabel('Intertia / WSS')
# Out:
# Text(0, 0.5, 'Intertia / WSS')

# %%
#Dari hasil diatas elbow nya dipilih pada angka 4,
# karena titik awal sebelum titik selanjutnya memiliki gap yang konstan atau
# titik setelah lekukan tajam sebelum mendatar
from sklearn.cluster import KMeans
kmeans_elbow = KMeans(n_clusters=4, random_state=0)
kmeans_elbow.fit(df_scalling.values)
# Out:
# KMeans(n_clusters=4, random_state=0)

# %%
#taruh hasil k-means elbow method ke df dengan nama kolom cluster_elbow
df['cluster_elbow'] = kmeans_elbow.labels_

# %%
df
# Out:
#           tinggi      berat deskripsi  cluster_elbow
# 0     158.114332  58.364240    Normal              0
# 1     160.344026  52.560155    Normal              0
# 2     161.486080  61.934852    Normal              0
# 3     182.459297  69.042108      Slim              2
# 4     184.462584  71.341076      Slim              2
# ...          ...        ...       ...            ...
# 8883  177.296550  74.905033      Slim              2
# 8884  151.605026  81.084183     Obese              3
# 8885  158.838120  61.779766    Normal              0
# 8886  156.592981  54.047666    Normal              0
# 8887  154.689225  86.413551     Obese              3
#
# [8888 rows x 4 columns]

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='berat', y='tinggi', hue='cluster_elbow')
# Out:
# <Axes: xlabel='berat', ylabel='tinggi'>

# %% [markdown]
# ### Bandingkan hasil dengan label anotator

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='berat', y='tinggi',hue='deskripsi')
# Out:
# <Axes: xlabel='berat', ylabel='tinggi'>

# %% [markdown]
# ### Hasil diatas ketika menggunakan elbow ialah optimal, karena cluster cocok dengan label anotator yang telah tersedia di deskripsi. Dengan kondisi :
# 1. Cluster 0 -> Normal
# 2. Cluster 1 -> Fat
# 3. Cluster 2 -> Slim
# 4. Cluster 3 -> Obese

# %% [markdown]
# ### 2. Via Score Plot

# %%
# !pip install yellowbrick
# Out:
# Requirement already satisfied: yellowbrick in C:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (1.5)
# Requirement already satisfied: matplotlib!=3.0.0,>=2.0.2 in C:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yellowbrick) (3.10.8)
# Requirement already satisfied: scipy>=1.0.0 in C:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yellowbrick) (1.17.1)
# Requirement already satisfied: scikit-learn>=1.0.0 in C:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yellowbrick) (1.8.0)
# Requirement already satisfied: numpy>=1.16.0 in C:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yellowbrick) (2.4.2)
# Requirement already satisfied: cycler>=0.10.0 in C:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from yellowbrick) (0.12.1)
# Requirement already satisfied: contourpy>=1.0.1 in C:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in C:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in C:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in C:\Users\ASUS\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (26.0)
# Requirement already satisfied: pillow>=8 in C:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in C:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in C:\Users\ASUS\AppData\Roaming\Python\Python314\site-packages (from matplotlib!=3.0.0,>=2.0.2->yellowbrick) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in C:\Users\ASUS\AppData\Roaming\Python\Python314\site-packages (from python-dateutil>=2.7->matplotlib!=3.0.0,>=2.0.2->yellowbrick) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in C:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in C:\Users\ASUS\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages (from scikit-learn>=1.0.0->yellowbrick) (3.6.0)
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Via Score Plot
from yellowbrick.cluster import KElbowVisualizer
k_means_via = KMeans()
# k is range of number of clusters.
visualizer = KElbowVisualizer(k_means_via, k=(1,11), timings= True, force_model=True)
visualizer.fit(df_scalling.values)        # Fit the data to the visualizer
plt.title('Distortion Via-Score Plot for K-Means Clustering')
plt.show()

# %%
# Dari hasil diatas K-nya dipilih pada angka 3,
# karena titik distorsinya bertemu pada nilai 3 di sumbu x
from sklearn.cluster import KMeans
kmeans_via = KMeans(n_clusters=3, random_state=0)
kmeans_via.fit(df_scalling.values)
# Out:
# KMeans(n_clusters=3, random_state=0)

# %%
#taruh hasil k-means via score method ke df dengan nama kolom cluster_via
df['cluster_via'] = kmeans_via.labels_

# %%
df
# Out:
#           tinggi      berat deskripsi  cluster_elbow  cluster_via
# 0     158.114332  58.364240    Normal              0            0
# 1     160.344026  52.560155    Normal              0            0
# 2     161.486080  61.934852    Normal              0            0
# 3     182.459297  69.042108      Slim              2            2
# 4     184.462584  71.341076      Slim              2            2
# ...          ...        ...       ...            ...          ...
# 8883  177.296550  74.905033      Slim              2            2
# 8884  151.605026  81.084183     Obese              3            1
# 8885  158.838120  61.779766    Normal              0            0
# 8886  156.592981  54.047666    Normal              0            0
# 8887  154.689225  86.413551     Obese              3            1
#
# [8888 rows x 5 columns]

# %% [markdown]
# ## TO DO !
# - Lakukan evaluasi pada k-means menggunakan via score secara visualisasi

# %%
#Lakukan evaluasi setelah dilakukan K-Means
#Bandingkan hasil cluster dengan distribusi data asli
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='berat', y='tinggi', hue='cluster_via')
# Out:
# <Axes: xlabel='berat', ylabel='tinggi'>

# %% [markdown]
# ### Bandingkan dengan label anotator

# %%
fig, ax = plt.subplots(figsize=(15,10))
sns.scatterplot(data=df, x='berat', y='tinggi', hue='deskripsi')
plt.title('Label Asli (Anotator)')
plt.show()

# %% [markdown]
# ### Tulis Interpretasi dari hasil evaluasi diatas :
# ### Isi disini
# Hasil evaluasi terlihat bahwa:
#
# Cluster 0 berada pada area berat menengah dengan tinggi relatif rendah. Cluster 1 berada pada area tinggi paling besar. Cluster 2 berada pada area berat lebih kecil dengan tinggi sedang.

# %% [markdown]
# ### Thank you :)
